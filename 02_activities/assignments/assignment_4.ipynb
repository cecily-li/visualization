# %% [markdown]
# # Data Visualization
#
# ## Assignment 4: Final Project
#
# ### Requirements:
# - We will finish this class by giving you the chance to use what you have learned in a practical context, by creating data visualizations from raw data.
# - Choose a dataset of interest from the [City of Toronto’s Open Data Portal](https://www.toronto.ca/city-government/data-research-maps/open-data/) or [Ontario’s Open Data Catalogue](https://data.ontario.ca/).
# - Using Python and one other data visualization software (Excel or free alternative, Tableau Public, any other tool you prefer), create two distinct visualizations from your dataset of choice.
# - For each visualization, describe and justify: (See below)
#     > What software did you use to create your data visualization?
#
#     > Who is your intended audience?
#
#     > What information or message are you trying to convey with your visualization?
#
#     > What design principles (substantive, perceptual, aesthetic) did you consider when making your visualization? How did you apply these principles? With what elements of your plots?
#
#     > How did you ensure that your data visualizations are reproducible? If the tool you used to make your data visualization is not reproducible, how will this impact your data visualization?
#
#     > How did you ensure that your data visualization is accessible?
#
#     > Who are the individuals and communities who might be impacted by your visualization?
#
#     > How did you choose which features of your chosen dataset to include or exclude from your visualization?
#
#     > What ‘underwater labour’ contributed to your final data visualization product?
#
# - This assignment is intentionally open-ended - you are free to create static or dynamic data visualizations, maps, or whatever form of data visualization you think best communicates your information to your audience of choice!
# - Total word count should not exceed **(as a maximum) 1000 words**
#
# ### Why am I doing this assignment?:
# - This ongoing assignment ensures active participation in the course, and assesses the learning outcomes:
# * Create and customize data visualizations from start to finish in Python
# * Apply general design principles to create accessible and equitable data visualizations
# * Use data visualization to tell a story
# - This would be a great project to include in your GitHub Portfolio – put in the effort to make it something worthy of showing prospective employers!
#
# ### Rubric:
#
# | Component         | Scoring  | Requirement                                                                 |
# |-------------------|----------|-----------------------------------------------------------------------------|
# | Data Visualizations | Complete/Incomplete | - Data visualizations are distinct from each other<br>- Data visualizations are clearly identified<br>- Different sources/rationales (text with two images of data, if visualizations are labeled)<br>- High-quality visuals (high resolution and clear data)<br>- Data visualizations follow best practices of accessibility |
# | Written Explanations | Complete/Incomplete | - All questions from assignment description are answered for each visualization<br>- Explanations are supported by course content or scholarly sources, where needed |
# | Code              | Complete/Incomplete | - All code is included as an appendix with your final submissions<br>- Code is clearly commented and reproducible |
#
# ## Submission Information
#
# 🚨 **Please review our [Assignment Submission Guide](https://github.com/UofT-DSI/onboarding/blob/main/onboarding_documents/submissions.md)** 🚨 for detailed instructions on how to format, branch, and submit your work. Following these guidelines is crucial for your submissions to be evaluated correctly.
#
# ### Submission Parameters:
# * Submission Due Date: `HH:MM AM/PM - DD/MM/YYYY`
# * The branch name for your repo should be: `assignment-4`
# * What to submit for this assignment:
#     * A folder/directory containing:
#         * This file (assignment_4.md)
#         * Two data visualizations
#         * Two markdown files for each both visualizations with their written descriptions.
#         * Link to your dataset of choice.
#         * Complete and commented code as an appendix (for your visualization made with Python, and for the other, if relevant)
# * What the pull request link should look like for this assignment: `https://github.com/<your_github_username>/visualization/pull/<pr_id>`
#     * Open a private window in your browser. Copy and paste the link to your pull request into the address bar. Make sure you can see your pull request properly. This helps the technical facilitator and learning support staff review your submission easily.
#
# Checklist:
# - [x] Create a branch called `assignment-4`.
# - [x] Ensure that the repository is public.
# - [x] Review [the PR description guidelines](https://github.com/UofT-DSI/onboarding/blob/main/onboarding_documents/submissions.md#guidelines-for-pull-request-descriptions) and adhere to them.
# - [x] Verify that the link is accessible in a private browser window.
#
# If you encounter any difficulties or have questions, please don't hesitate to reach out to our team via our Slack at `#cohort-3-help`. Our Technical Facilitators and Learning Support staff are here to help you navigate any challenges.

# %%
import csv
with open ('Apartment Building Evaluations 2023 - current.csv') as f:
    reader = csv.reader(f)
    for row in reader:
        print(row)
# Out:
# ['_id', 'RSN', 'YEAR REGISTERED', 'YEAR BUILT', 'YEAR EVALUATED', 'PROPERTY TYPE', 'WARD', 'WARDNAME', 'SITE ADDRESS', 'CONFIRMED STOREYS', 'CONFIRMED UNITS', 'EVALUATION COMPLETED ON', 'CURRENT BUILDING EVAL SCORE', 'PROACTIVE BUILDING SCORE', 'CURRENT REACTIVE SCORE', 'NO OF AREAS EVALUATED', 'NUMBERING OF PROPERTY', 'EXTERIOR GROUNDS', 'FENCING', 'RETAINING WALLS', 'CATCH BASINS / STORM DRAINAGE', 'BUILDING EXTERIOR', 'BALCONY GUARDS', 'WINDOWS', 'EXT. RECEPTACLE STORAGE AREA', 'EXTERIOR WALKWAYS', 'CLOTHING DROP BOXES', 'ACCESSORY BUILDINGS', 'INTERCOM', 'EMERGENCY CONTACT SIGN', 'LOBBY - WALLS AND CEILING', 'LOBBY FLOORS', 'LAUNDRY ROOM', 'INT. RECEPTACLE STORAGE AREA', 'MAIL RECEPTACLES', 'EXTERIOR DOORS', 'STORAGE AREAS/LOCKERS MAINT.', 'POOLS', 'OTHER AMENITIES', 'PARKING AREAS', 'ABANDONED EQUIP./DERELICT VEH.', 'GARBAGE/COMPACTOR ROOM', 'ELEVATOR MAINTENANCE', 'ELEVATOR COSMETICS', 'INT. HALLWAY - WALLS / CEILING', 'INTERIOR HALLWAY FLOORS', 'INT. LOBBY / HALLWAY LIGHTING',
# ...

# %%
#Import packages
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy
import PIL
import requests

# %%
df = pd.read_csv('Apartment Building Evaluations 2023 - current.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2657 entries, 0 to 2656
# Data columns (total 71 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   _id                             2657 non-null   int64
#  1   RSN                             2657 non-null   int64
#  2   YEAR REGISTERED                 2613 non-null   float64
#  3   YEAR BUILT                      2646 non-null   float64
#  4   YEAR EVALUATED                  2657 non-null   int64
#  5   PROPERTY TYPE                   2657 non-null   object
#  6   WARD                            2657 non-null   object
#  7   WARDNAME                        2656 non-null   object
#  8   SITE ADDRESS                    2657 non-null   object
#  9   CONFIRMED STOREYS               2657 non-null   int64
#  10  CONFIRMED UNITS                 2657 non-null   int64
#  11  EVALUATION COMPLETED ON         2656 non-null   object
# ...

# %%
df.select_dtypes("number")
# Out:
#        _id      RSN  YEAR REGISTERED  YEAR BUILT  YEAR EVALUATED  \
# 0        1  4154710           2017.0      1959.0            2024
# 1        2  4154639           2017.0      1969.0            2023
# 2        3  4156414           2017.0      1983.0            2023
# 3        4  4156200           2017.0      1987.0            2023
# 4        5  4154234           2017.0      1971.0            2024
# ...    ...      ...              ...         ...             ...
# 2652  2653  4155631              NaN      2019.0            2024
# 2653  2654  4155630           2017.0      1957.0            2023
# 2654  2655  4155444           2017.0      1969.0            2023
# 2655  2656  4156153           2017.0      1969.0            2023
# 2656  2657  4232595           2017.0      1963.0            2023
#
#       CONFIRMED STOREYS  CONFIRMED UNITS  CURRENT BUILDING EVAL SCORE  \
# 0                     4               39                         78.0
# ...

# %%
y = df['CURRENT BUILDING EVAL SCORE']
x1 = df['YEAR BUILT']
x2 = df ['CONFIRMED STOREYS']
#fig, (ax1,ax2) = plt.subplots(1,2,figsize=(25, 18))

#ax1.scatter(x1, y,
#color = "indigo")

#Define 2 axes to have 2 plots side by side
fig,(ax1, ax2) = plt.subplots(ncols=2,
nrows=1,
figsize=(30, 16))

ax1.scatter(x1,y,
            marker='o',
            color = 'blue') #scatter plot of building evaluation score against year the apartment was built (Figure 1)
ax2.scatter(x2,y,
        color = 'black') #scatter plot of building evaluation score against the number of storeys of the building (Figure 2)

#Update axes labels and title for figure 1
ax1.set_xlabel('Year Built')
ax1.set_ylabel('Building Evaluation Score')
ax1.set_title('Figure 1: Building Evaluation Score by Year Built')

#Update axes labels and title for figure 2
ax2.set_xlabel('Number of Storeys')
ax2.set_ylabel('Building Evaluation Score')
ax2.set_title('Figure 2: Building Evaluation Score by Number of Storeys')
# Out:
# Text(0.5, 1.0, 'Figure 2: Building Evaluation Score by Number of Storeys')

# %% [markdown]
#    > What software did you use to create your data visualization?
#
# Python
#
#    > Who is your intended audience?
#
# Prospective renters and owners of apartments in the City of Toronto.
#    > What information or message are you trying to convey with your visualization?
#
# The relationships between the year the apartment was built + the number of storeys of each apartment and the building evaluation score.
#    > What design principles (substantive, perceptual, aesthetic) did you consider when making your visualization? How did you apply these principles? With what elements of your plots?
#
# Substantive, perceptual, and aesthetic by making the figures large enough to read individual data points, easily readable using axes labels and titles, different colours to indicate the difference between the two figures, and side by side placement to see the difference between the two dependent variables.
#    > How did you ensure that your data visualizations are reproducible? If the tool you used to make your data visualization is not reproducible, how will this impact your data visualization?
#
# The dataset is a csv file and there were no random numbers generated. This visualization can be generated by anyone who has access to the dataset.
#    > How did you ensure that your data visualization is accessible?
#
# Intentionally chose colours that can be seen by people with visual impairments such as colourblindness, made the figures a larger size that makes it easier to read.
#    > Who are the individuals and communities who might be impacted by your visualization?
#
# Individuals in the renter and buyer/seller market for apartments in the city of Toronto, realtors who are listing these properties or making the decision of whether or not to take a listing in one of these apartments, city officials whose responsibility it is to monitor and ensure buildings are up to code, property managers, etc.
#
#    > How did you choose which features of your chosen dataset to include or exclude from your visualization?
#
# Through evaluation of the different variables in the table (see code blocks above)
#    > What ‘underwater labour’ contributed to your final data visualization product?
#
# Gathering and cleaning of the data to present it in the dataset that was downloaded from the City of Toronto website.

# %% [markdown]
# **See link for Tableau visual: https://public.tableau.com/views/DSIVisualizationAssignment4/Sheet1?:language=en-US&:sid=&:redirect=auth&:display_count=n&:origin=viz_share_link**

# %% [markdown]
#    > What software did you use to create your data visualization?
#
# Tableau Public
#
#    > Who is your intended audience?
#
# Prospective owners and renters of apartments in toronto, property managers, realtors, people who are looking to gain a better understanding of the toronto apartment landscape.
#    > What information or message are you trying to convey with your visualization?
#
# Density of Toronto apartments in different areas throughout the GTA, and their respective property types (i.e., private, social housing, etc.) and building evaluation scores.
#    > What design principles (substantive, perceptual, aesthetic) did you consider when making your visualization? How did you apply these principles? With what elements of your plots?
#
# The map is interactive and users can zoom in or out depending on what type of evaluation they are looking for. Additionally, users can employ the search function at the top left corner of the visual to search for buildings in specific areas of interest.
#    > How did you ensure that your data visualizations are reproducible? If the tool you used to make your data visualization is not reproducible, how will this impact your data visualization?
#
# Used data that was provided in the original data set, and updated only data types without changing any source data. Users can reproduce this visualization using the same data set and parameters in Tableau.
#    > How did you ensure that your data visualization is accessible?
#
# Used Tableau to make it more interactive, allowing users to zoom in and out, pan around the map, and pin any data points to the forefront to analyze specific areas or properties.
#    > Who are the individuals and communities who might be impacted by your visualization?
#
# Prospective owners and renters of apartments in toronto, property managers, realtors, people such as city officials or individuals from another area of Canada/another country who are looking to gain a better understanding of the toronto apartment landscape.
#    > How did you choose which features of your chosen dataset to include or exclude from your visualization?
#
# Assessed usability and relevance from the perspective of an end user to determine which data points would be most useful in evaluation of the data set.
#    > What ‘underwater labour’ contributed to your final data visualization product?
#
# Data cleaning and presentation, including the longitude and latitude pinpoints which made this map visual possible.
